# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cols = ["kinetic", "potenital", "combined", "temperature"]
df = pd.read_csv(
    "/home/sauerbach/HPC/MolecularDynamics/static/metrics.csv", header=None, names=cols, sep='\s+'
)

df.head()
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.
#     kinetic  potenital  combined  temperature
# 0   2.86413   -14138.5  -14135.6      5.72407
# 1  10.69840   -14143.9  -14133.2     21.38110
# 2  21.59330   -14152.6  -14131.0     43.15500
# 3  34.42680   -14163.3  -14128.8     68.80330
# 4  48.22460   -14175.1  -14126.8     96.37880

# %%
df.plot(y=[3])
df.plot(y=[2])
# Out:
# <AxesSubplot:>

# %%
es = []
ts = []
for i in range(50):
    e = df.combined[i*3000+2000:i*3000+3000].mean()
    es.append(e)
    # print(e, df.combined[i*300+200:i*300+300].std())
    t = df.temperature[i*3000+2000:i*3000+3000].mean()
    ts.append(t)
    # print(t, df.temperature[i*300+200:i*300+300].std())

    # # c.append(e/t)
    # plt.axvline(i*3000+1000, c='blue')
    # plt.axvline(i*3000+2000, c='red')
# plt.plot(df.combined)
plt.plot(ts, es)

# %%
plt.plot(df.temperature, df.combined)
